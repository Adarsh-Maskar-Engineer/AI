# %%
from dotenv import load_dotenv
load_dotenv()
import os

if os.environ.get("OPENAI_API_KEY"):
    print("OPENAI_API_KEY is set.")
# Out:
# OPENAI_API_KEY is set.

# %% [markdown]
# ## **OPENAI SDK**

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input="fact on data engineering three lines"
)

print(response.output_text)
# Out:
# Data engineering builds and maintains pipelines that collect, clean, and transform raw data into usable formats.
# It requires solving scalability, reliability, and latency challenges across distributed systems.
# High-quality data engineering accelerates analytics and machine learning, directly improving business decisions.
