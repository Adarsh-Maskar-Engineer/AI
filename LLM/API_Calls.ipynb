# %% [markdown]
# ## **OPENAI SDK**

# %%
from openai import OpenAI
client = OpenAI()

response = client.responses.create(
    model="gpt-5-mini",
    input="Tell me fun fact about Data Engineering Domain"
)

print(response.output_text)
