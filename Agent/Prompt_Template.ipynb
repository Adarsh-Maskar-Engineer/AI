# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
import os
from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model_name="gpt-5-mini")

# %%
messages = [
    {"role": "system", "content": "You are a romantic poet"},
    {"role": "user", "content": "write a poem for mountain and river"}
]


response = llm.invoke(messages)
response.content
# Out:
# 'They met before maps, before names were given —\nyou, a slow cathedral of stone, standing\nwith your jaw set against the sky;\nI, a restless silver braid, unspooling\nfrom secret snow to the sea’s wide mouth.\n\nYou keep the fossils of light in your ribs,\nhold storms like prayers behind your teeth;\nI remember every face the rain has made,\nlearned language from the moss and the shore.\nWhen I touch you, I sing in a softer key,\nand your granite answers with echoes of dusk.\n\nSometimes I scold you for your patience,\nfor hoarding the sun on high, for remembering\nthe long cold of winter. You laugh like thunder,\nstones shifting with a slow, intimate knowledge.\nWhen night pours its ink across your shoulders,\nI braid my surface with moon, and we are both transformed.\n\nBetween your stern shadow and my rippled skin\na valley pulses — a small cathedral of reeds,\nwhere lovers have buried words and kept them warm.\nWe do not hurry; we do not flee. Your silence\nis my harbor; my movement is your language.\n\nIf the world forgets us, let it. We have a map\ndrawn by foot and flow: the first frost I taste,\nthe last bird that takes your cliff for a wing.\nWhere you rise, I begin; where I end, you remember me —\ntwo vows written in water and stone, unending.'

# %%
my_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a genZ poet."),
        ("user", "Write a poem about the {topic}.")
    ]
)
mountains_prompt = my_template.invoke({"topic": "beauty of mountains"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a genZ poet.', additional_kwargs={}, response_metadata={}), HumanMessage(content='Write a poem about the beauty of mountains.', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## Chains

# %%
# Step-1: Create a prompt template
my_template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a genZ poet."),
        ("user", "Write a poem about the {topic}.")
    ]
)

# Step-2: Sending the prompt to the LLM
from pydantic import BaseModel, Field

class llm_schema(BaseModel):
    query: str = Field(description="The query that was asked to the LLM")
    answer: str = Field(description="The answer generated by the LLM")
    total_tokens: int = Field(description="The total number of tokens used in the LLM response")

llm_structured = llm.with_structured_output(llm_schema)

# Step-3: Parsing the output
from langchain_core.output_parsers import PydanticOutputParser
parser = PydanticOutputParser(pydantic_object=llm_schema)


# Final Step: Putting it all together

my_chain = my_template | llm_structured
